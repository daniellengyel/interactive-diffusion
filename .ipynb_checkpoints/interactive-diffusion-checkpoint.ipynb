# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

import itertools
# import seaborn as sb

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.1.1'

# %% [markdown]
# Input for all functions has the meshgrid form. Output is supposed to be in the same form.
#
# Input for all gradient functions has meshgrid form. Output is supposed to be in the same form.

# %%
def AckleyProblem(xs):
    a = np.exp(-0.2 * np.sqrt(1./len(xs) * np.square(np.linalg.norm(xs, axis=0))))
    b = - np.exp(1./len(xs) * np.sum(np.cos(2*np.pi*xs), axis=0))
    return -20 * a + b + 20 + np.exp(1)

def GradAckleyProblem(xs):
    """del H/del xi = -20 * -0.2 * xi / sqrt(1/n sum_j xj) * a + 2 pi sin(2 pi xi)/n * b"""
    a = np.exp(-0.2 * np.sqrt(1./len(xs) * np.square(np.linalg.norm(xs, axis=0))))
    b = - np.exp(1./len(xs) * np.sum(np.cos(2*np.pi*xs), axis=0))
    a_p = -0.2 * xs / np.sqrt(1./len(xs) * np.square(np.linalg.norm(xs, axis=0)))
    b_p = 2 * np.pi * np.sin(2 * np.pi * xs)/len(xs)
    return np.nan_to_num(-20 * a_p * a + b_p * b) # only when norm(x) == 0 do we have nan and we know the grad is zero there

# %%
def QuadraticFunctionInit(A, b):
    def QuadraticFunction(xs):
        out_shape = xs[0].shape
        xs = np.array([x.flatten() for x in xs])
        return (np.diag(np.dot(xs.T, np.dot(A, xs))) + b).reshape(out_shape)
    return QuadraticFunction

def GradQuadraticFunctionInit(A):
    def GradQuadraticFunction(xs):
        out_shape = xs[0].shape
        xs = np.array([x.flatten() for x in xs])
        grad = np.dot(xs.T, A + A.T).T
        return np.array([[g] for g in grad])
    return GradQuadraticFunction

# %%
A = np.array([[1, 0], [0, 1]])
b = 0
f = QuadraticFunctionInit(A, b)
f_grad = GradQuadraticFunctionInit(A)

xs = np.linspace(-100, 100, 100)
ys = np.linspace(-100, 100, 100)
inp = np.array(np.meshgrid(xs, ys))
out = f(inp)

# %%
f_grad(np.array([[[1]], [[2]]]))
# Out:
# array([[[2]],
#
#        [[4]]])

# %%
fig = plt.figure()
fig.set_size_inches(18.5, 10.5)
ax = fig.gca(projection="3d")

ax.view_init(45, 20)

ax.plot_surface(inp[0], inp[1], out, rstride=1, cstride=1,
                cmap='viridis', edgecolor='none', alpha=1)

# %%
def grad_descent(func, grad_func, x_curr, eps,gamma):
    x_curr = np.array(x_curr, dtype=np.float)
    path = [x_curr]
    t = 0
    while True:
        print(x_curr)
        x_next = x_curr - gamma(t)*grad_func(x_curr)
        print(x_next)
        path.append(x_next)
        
        if np.abs(func(x_next) - func(x_curr)) < eps: # TODO check what happens with more samples
            break
        x_curr = x_next
        t += 1
    return path

# %%
def simulated_annealing(func, grad_func, x_curr, eps, gamma, temperature)

# %%
def gamma(t):
    return 0.5/((t // 20) + 1)

path = grad_descent(AckleyProblem, GradAckleyProblem, [[[1.]], [[2.]]], 0.00001, gamma)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-32-0b7f63fe3264> in <module>
#       2     return 0.5/((t // 20) + 1)
#       3
# ----> 4 path = grad_descent(AckleyProblem, GradAckleyProblem, [[[1.]], [[2.]]], 0.00001, gamma)
#
# <ipython-input-31-d870549e2a09> in grad_descent(func, grad_func, x_curr, eps, gamma)
#       4     t = 0
#       5     while True:
# ----> 6         print(x_next)
#       7         x_next = x_curr - gamma(t)*grad_func(x_curr)
#       8         path.append(x_next)
#
# UnboundLocalError: local variable 'x_next' referenced before assignment

# %%
path = grad_descent(QuadraticFunctionInit(A, b), GradQuadraticFunctionInit(A), [[[1.]], [[2.]]], 0.00001, gamma)
# Out:
# [[[1.]]
#
#  [[2.]]]
# [[[0.]]
#
#  [[0.]]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-162db9a62f75> in <module>
# ----> 1 path = grad_descent(QuadraticFunctionInit(A, b), GradQuadraticFunctionInit(A), [[[1.]], [[2.]]], 0.00001, gamma)
#
# <ipython-input-53-a73f252b1bf4> in grad_descent(func, grad_func, x_curr, eps, gamma)
#       9         path.append(x_next)
#      10
# ---> 11         if np.abs(func(x_next) - func(x_curr), axis=0) < eps:
#      12             break
#      13         x_curr = x_next
#
# TypeError: 'axis' is an invalid keyword to ufunc 'absolute'

# %%
path_x, path_y = np.concatenate(path, axis=2)

inp_path = np.array([path_x[0], path_y[0]])

out_path = AckleyProblem(inp_path)

# %%
# xs = np.linspace(-100, 1000, 10000)
# ys = np.linspace(-100, 1000, 10000)

xs = np.linspace(-2, 2, 200)
ys = np.linspace(-2, 2, 200)

inp = np.array(np.meshgrid(xs, ys))
out = AckleyProblem(inp)

# %%
fig = plt.figure()
fig.set_size_inches(18.5, 10.5)

plt.plot(path_x[0], path_y[0])
plt.show()

# %%
fig = plt.figure()
fig.set_size_inches(18.5, 10.5)

ax = fig.gca(projection='3d')

ax.view_init(50, 35)

ax.plot_surface(inp[0], inp[1], out, rstride=1, cstride=1,
                cmap='viridis', edgecolor='none', alpha=0.1)

ax.plot3D(path_x[0], path_y[0], out_path, 'red')


# plt.imshow(out, cmap='hot', interpolation='nearest')
# plt.show()
